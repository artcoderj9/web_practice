# %% [markdown]
# # Linear Regression using TensorFlow

# %% [markdown]
# ### Hypothesis
# * H(x) = W * x + b
#
# ### Cost Function
# * mean square

# %%
import tensorflow as tf

x_train = [1, 2, 3]
y_train = [1, 2, 3]

w = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = w * x_train + b

cost = tf.reduce_mean(tf.square(hypothesis - y_train))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)

train = optimizer.minimize(cost)

sess = tf.Session()

sess.run(tf.global_variables_initializer())

for i in range(1000):
    sess.run(train)
    if i % 20 == 0:
        print(i, sess.run(cost), sess.run(w), sess.run(b))
# Out:
# 0 0.38981965 [1.7302046] [-1.275061]
# 20 0.23426981 [1.5742087] [-1.2686646]
# 40 0.21168156 [1.5356367] [-1.2141389]
# 60 0.19224279 [1.5093604] [-1.1575639]
# 80 0.17459798 [1.4853175] [-1.103209]
# 100 0.15857257 [1.4624994] [-1.0513667]
# 120 0.14401822 [1.4407626] [-1.0019567]
# 140 0.13079968 [1.4200484] [-0.95486856]
# 160 0.11879435 [1.4003077] [-0.90999323]
# 180 0.10789093 [1.3814945] [-0.8672269]
# 200 0.09798828 [1.3635658] [-0.8264705]
# 220 0.08899445 [1.3464793] [-0.7876293]
# 240 0.0808262 [1.3301961] [-0.7506135]
# 260 0.07340761 [1.3146781] [-0.71533734]
# 280 0.06666996 [1.2998892] [-0.681719]
# 300 0.060550753 [1.2857958] [-0.6496807]
# 320 0.054993138 [1.2723643] [-0.61914814]
# 340 0.04994565 [1.259564] [-0.5900504]
# 360 0.045361433 [1.2473656] [-0.56232005]
# 380 0.04119797 [1.2357403] [-0.535893]
# 400 0.037416656 [1.2246615] [-0.51070803]
# 420 0.033982422 [1.2141032] [-0.4867068]
# 440 0.030863391 [1.2040411] [-0.4638334]
# 460 0.028030587 [1.1944518] [-0.44203487]
# 480 0.025457846 [1.1853135] [-0.42126083]
# 500 0.023121223 [1.1766043] [-0.4014632]
# 520 0.020999087 [1.1683046] [-0.38259587]
# 540 0.0190717 [1.1603949] [-0.36461532]
# 560 0.017321229 [1.1528571] [-0.3474798]
# 580 0.015731415 [1.1456733] [-0.33114955]
# 600 0.014287525 [1.1388271] [-0.31558678]
# 620 0.012976178 [1.1323029] [-0.30075535]
# 640 0.011785149 [1.126085] [-0.286621]
# 660 0.010703482 [1.1201596] [-0.27315098]
# 680 0.0097210705 [1.1145126] [-0.26031387]
# 700 0.008828833 [1.1091309] [-0.24808006]
# 720 0.008018498 [1.1040021] [-0.2364212]
# 740 0.0072825192 [1.0991144] [-0.22531034]
# 760 0.006614106 [1.0944564] [-0.21472156]
# 780 0.0060070255 [1.0900172] [-0.20463042]
# 800 0.0054556807 [1.0857868] [-0.19501352]
# 820 0.0049549285 [1.081755] [-0.18584864]
# 840 0.0045001525 [1.0779128] [-0.17711434]
# 860 0.004087114 [1.0742513] [-0.16879062]
# 880 0.0037119805 [1.0707618] [-0.1608581]
# 900 0.0033712834 [1.0674363] [-0.15329841]
# 920 0.0030618438 [1.064267] [-0.14609398]
# 940 0.002780828 [1.0612469] [-0.13922817]
# 960 0.0025255966 [1.0583683] [-0.13268502]
# 980 0.0022937816 [1.0556253] [-0.12644932]
